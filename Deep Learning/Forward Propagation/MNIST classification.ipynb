# %%
import tensorflow
from  tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(X_train[2])

# %%
X_train[4].shape
# Out:
# (28, 28)

# %%
model = Sequential()

# %%
model.add(Flatten(input_shape = (28 , 28)))
model.add(Dense(128 , activation = 'relu'))
model.add(Dense(32 , activation = 'relu'))
model.add(Dense(10 , activation = 'softmax'))
# Out:
# /home/subhamoy/miniforge3/envs/tf_gpu/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1765630531.181407    4623 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4872 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,938 (409.91 KB)
#  Trainable params: 104,938 (409.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss = 'sparse_categorical_crossentropy' , optimizer='Adam' , metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=25 , validation_split=0.2)
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9861 - loss: 0.0689 - val_accuracy: 0.9858 - val_loss: 0.0470
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9873 - loss: 0.0583 - val_accuracy: 0.9836 - val_loss: 0.0654
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9880 - loss: 0.0517 - val_accuracy: 0.9855 - val_loss: 0.0577
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9881 - loss: 0.0511 - val_accuracy: 0.9881 - val_loss: 0.0535
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9896 - loss: 0.0458 - val_accuracy: 0.9862 - val_loss: 0.0680
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9896 - loss: 0.0415 - val_accuracy: 0.9814 - val_loss: 0.0913
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9895 - loss: 0.0453 - val_accuracy: 0.9843 - val_loss: 0.0773
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9892 - loss: 0.0517 - val_accuracy: 0.9833 - val_loss: 0.1008
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9889 - loss: 0.0487 - val_accuracy: 0.9868 - val_loss: 0.0708
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9904 - loss: 0.0410 - val_accuracy: 0.9793 - val_loss: 0.1340
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9909 - loss: 0.0395 - val_accuracy: 0.9837 - val_loss: 0.0877
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9911 - loss: 0.0437 - val_accuracy: 0.9837 - val_loss: 0.0824
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9887 - loss: 0.0541 - val_accuracy: 0.9801 - val_loss: 0.1077
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9900 - loss: 0.0471 - val_accuracy: 0.9816 - val_loss: 0.1301
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9894 - loss: 0.0451 - val_accuracy: 0.9792 - val_loss: 0.1818
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9910 - loss: 0.0404 - val_accuracy: 0.9841 - val_loss: 0.0891
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9914 - loss: 0.0445 - val_accuracy: 0.9812 - val_loss: 0.1184
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9910 - loss: 0.0376 - val_accuracy: 0.9850 - val_loss: 0.1213
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9911 - loss: 0.0439 - val_accuracy: 0.9825 - val_loss: 0.1388
# Epoch 20/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9902 - loss: 0.0486 - val_accuracy: 0.9832 - val_loss: 0.1441
# Epoch 21/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9907 - loss: 0.0419 - val_accuracy: 0.9815 - val_loss: 0.1488
# Epoch 22/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9909 - loss: 0.0407 - val_accuracy: 0.9811 - val_loss: 0.1843
# Epoch 23/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9913 - loss: 0.0365 - val_accuracy: 0.9818 - val_loss: 0.1502
# Epoch 24/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9905 - loss: 0.0482 - val_accuracy: 0.9686 - val_loss: 0.1969
# Epoch 25/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9898 - loss: 0.0459 - val_accuracy: 0.9817 - val_loss: 0.1558

# %%
y_prob = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_prob
# Out:
# array([[7.0704756e-40, 2.3967764e-26, 3.3939433e-30, ..., 1.0000000e+00,
#         1.4474286e-16, 3.4276805e-08],
#        [0.0000000e+00, 1.4012985e-45, 1.0000000e+00, ..., 1.3472877e-27,
#         1.3943878e-36, 0.0000000e+00],
#        [0.0000000e+00, 1.0000000e+00, 1.7095841e-43, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [2.8025969e-45, 0.0000000e+00, 1.4012985e-45, ..., 0.0000000e+00,
#         1.6049720e-30, 8.0017742e-13],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         2.8130621e-33, 2.3952439e-31],
#        [2.8025969e-45, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], shape=(10000, 10), dtype=float32)

# %%
y_pred = y_prob.argmax(axis = 1)

# %%
y_pred
# Out:
# array([7, 2, 1, ..., 4, 5, 6], shape=(10000,))

# %%
plt.imshow(X_test[0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9702

# %%
plt.plot(history.history['loss'] , label = "Loss")
plt.plot(history.history['val_loss'] , label="Val Loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'] , label = "Acc")
plt.plot(history.history['val_accuracy'] , label="Val Acc")
plt.legend()
plt.show()

# %%
model.predict(X_test[20].reshape(1 , 28 , 28)).argmax(axis = 1)[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# np.int64(9)

# %%
X_test.shape -> 1 , 28 , 28 * 10000
# Out:
# (10000, 28, 28)

# %%
X_test[20].shape
# Out:
# (28, 28)

# %%
plt.imshow(X_test[20])
